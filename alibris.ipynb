# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

import os
import random


bookDataLocation = "resources/books.csv"

# %%
df = pd.read_csv(bookDataLocation)

ISBN_list = pd.DataFrame(df)

# def random_book():
#     randomBook = random.randint(1,10000)
#     book = df.loc[df["bookID"] == randomBook, ["title", "authors", "isbn"]]
#     return(book)
    
ISBN_list=ISBN_list[["title", "authors", "isbn13"]]
ISBN_list
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Sorcerer's Stone (Harry P...
# 3      Harry Potter and the Chamber of Secrets (Harry...
# 4      Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                  ...
# 13709                                     M Is for Magic
# 13710                                       Black Orchid
# 13711                        InterWorld (InterWorld  #1)
# 13712                                The Faeries' Oracle
# 13713                      The World of The Dark Crystal
#
#                              authors        isbn13
# 0         J.K. Rowling-Mary GrandPré  9.780440e+12
# 1         J.K. Rowling-Mary GrandPré  9.780440e+12
# 2         J.K. Rowling-Mary GrandPré  9.780440e+12
# 3                       J.K. Rowling  9.780440e+12
# ...

# %%
#Links

#links=ISBN_list.isbn13.to_list()
links

# %%
#Extract Power tool data

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

alibris_pandas_df = pd.DataFrame([])

#This doesn't work right now because there isn't a list of links
for x in links:

    url = (f'https://www.alibris.com/booksearch?keyword='+x)
    browser.visit(url)
    for y in range(1):
        # HTML object
        html = browser.html
        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')
    try:
        # Retrieve all elements that contain book information
        price = soup.find('meta',itemprop='price')['content']
        print("this is working")
        
        # Iterate through each book
        if price != 0:
            alibris_pandas_df = alibris_pandas_df.append(pd.DataFrame({'ISBN':x,'Alibris Price': price}, index=[0]), ignore_index=True)
            print(price)
    except TypeError:
        print("Oh Shit")
# Out:
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 1.99
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 1.99
# this is working
# 0
# this is working
# 0
# this is working
# 1.47
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0.99
# Oh Shit
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0.99
# this is working
# 0.99
# this is working
# 0
# this is working
# 1.98
# this is working
# 0
# this is working
# 0
# this is working
# 1.99
# this is working
# 0.99
# this is working
# 0
# this is working
# 0
# this is working
# 0
# this is working
# 0.99
# this is working
# 0
# Oh Shit
# this is working
# 4.67
# ...

# %%
alibris_pandas_df
# Out:
#           ISBN Alibris Price
# 0    439785960             0
# 1    439358078             0
# 2    439554934             0
# 3    439554896             0
# 4   043965548X          1.99
# 5    439682584             0
# 6    976540606             0
# 7    439827604             0
# 8    517226952             0
# 9    345453743             0
# 10  1400052920          1.99
# 11   739322206             0
# 12   517149257             0
# 13  076790818X          1.47
# 14   767915062             0
# 15   767910435             0
# 16   767903862             0
# 17  076790382X          0.99
# 18   380713802             0
# 19   380727501             0
# 20   380715430             0
# 21   345538374             0
# 22   618517650             0
# 23   618346244             0
# 24   618346252             0
# 25   618260587             0
# 26   618391002             0
# 27   618510826             0
# 28   618153977             0
# 29  193337201X          0.99
# 30  097669400X          0.99
# ...

# %%
#alibris_pandas_df.to_csv(r"/Alibris.csv")
