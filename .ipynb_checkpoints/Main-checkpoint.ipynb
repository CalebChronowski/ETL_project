# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

# %%
link = 'http://www.topshelfcomix.com/catalog/isbn-list'

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
book_pandas_df = pd.DataFrame([])
browser.visit(link)
for y in range(1):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    air_comp = soup.find_all('div', class_='isbn-item')
    
    # Iterate through each book
    for air_comps in air_comp:
        part = air_comps.find('span',class_='isbn-number').text
        fact = air_comps.find('span', class_='isbn-info')
        price = air_comps.find('span', class_='isbn-info').text
        price = price.split("$")
        if len(price)<2:
            index=0
        else:
            index=1
        
        for facts in fact:
            desc = air_comps.find('a').text
        if len(price[index]) > 6:
            print("IT WORKED")
        else:
            book_pandas_df = book_pandas_df.append(pd.DataFrame({'ISBN': part, 'Title': desc,'Price':price[index]}, index=[0]), ignore_index=True)
    try:
        plwk = soup.find_all('a',rel='nofollow').text
        browser.click_link_by_text(plwk)
    except:
        print("Scraping Complete")
# Out:
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# Scraping Complete

# %%
book_pandas_df.head()
# Out:
#                 ISBN                                    Title  Price
# 0  978-1-891830-75-4                                 110 Per¢  12.95
# 1  978-1-60309-050-6                    The 120 Days of Simon  14.95
# 2  978-1-891830-71-6               AEIOU or Any Easy Intimacy  12.00
# 3  978-1-60309-025-4               Alec: The Years Have Pants  35.00
# 4  978-1-60309-047-6  Alec: The Years Have Pants -- HARDCOVER  49.95

# %%
links = book_pandas_df["ISBN"]

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

alibris_pandas_df = pd.DataFrame([])

#This doesn't work right now because there isn't a list of links
for x in links:

    url = (f'https://www.alibris.com/booksearch?keyword='+x)
    browser.visit(url)
    for y in range(1):
        # HTML object
        html = browser.html
        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')
        time.sleep(3)
    try:
        # Retrieve all elements that contain book information
        price = soup.find('meta',itemprop='price')['content']
        print("this is working")
        
        # Iterate through each book
        if price != 0:
            alibris_pandas_df = alibris_pandas_df.append(pd.DataFrame({'ISBN':x,'Alibris Price': price}, index=[0]), ignore_index=True)
            print(price)
    except TypeError:
        print("Oh Shit")
# Out:
# this is working
# 3.40
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 3.33
# this is working
# 6.74
# this is working
# 1.45
# this is working
# 1.45
# this is working
# 1.45
# this is working
# 2.72
# this is working
# 2.77
# this is working
# 1.99
# this is working
# 1.48
# this is working
# 7.49
# this is working
# 25.56
# this is working
# 0
# this is working
# 17.81
# this is working
# 0
# this is working
# 1.49
# this is working
# 0.99
# this is working
# 1.46
# this is working
# 5.94
# this is working
# 1.80
# this is working
# 6.00
# this is working
# 12.51
# this is working
# 3.74
# this is working
# 1.99
# this is working
# 4.32
# this is working
# 2.77
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# this is working
# 1.79
# this is working
# 3.24
# this is working
# 1.21
# this is working
# 6.25
# this is working
# 8.64
# this is working
# 1.99
# this is working
# 5.15
# this is working
# 4.10
# this is working
# 12.92
# this is working
# 1.45
# this is working
# 4.24
# this is working
# 0.99
# this is working
# 0.99
# this is working
# 12.92
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 0.99
# this is working
# 110.51
# this is working
# 3.73
# this is working
# 0.99
# this is working
# 0.99
# this is working
# 9.99
# this is working
# 0
# this is working
# 0.99
# this is working
# 1.00
# this is working
# 12.56
# this is working
# 19.99
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 7.15
# this is working
# 25.29
# this is working
# 3.71
# Oh Shit
# Oh Shit
# Oh Shit
# this is working
# 2.83
# this is working
# 0.99
# this is working
# 2.50
# this is working
# 0.99
# this is working
# 1.80
# this is working
# 1.80
# this is working
# 2.99
# this is working
# 0.99
# this is working
# 7.68
# this is working
# 6.40
# this is working
# 2.45
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 0.99
# this is working
# 3.25
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 4.66
# this is working
# 0.99
# this is working
# 8.03
# this is working
# 1.57
# this is working
# 1.45
# this is working
# 1.45
# this is working
# 2.99
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 0.99
# this is working
# 2.94
# this is working
# 4.54
# this is working
# 6.38
# this is working
# 0.99
# this is working
# 70.08
# this is working
# 0.99
# this is working
# 0.99
# Oh Shit
# this is working
# 24.99
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 0.99
# this is working
# 1.45
# Oh Shit
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 3.17
# this is working
# 8.03
# this is working
# 12.89
# Oh Shit
# Oh Shit
# Oh Shit
# this is working
# 0.99
# this is working
# 2.00
# this is working
# 0.99
# this is working
# 5.73
# this is working
# 1.50
# this is working
# 3.25
# this is working
# 2.69
# this is working
# 34.55
# this is working
# 2.99
# this is working
# 0.99
# this is working
# 0.99
# this is working
# 1.93
# this is working
# 0.99
# this is working
# 2.50
# Oh Shit
# this is working
# 18.02
# this is working
# 1.97
# this is working
# 0
# this is working
# 11.46
# this is working
# 1.03
# this is working
# 0
# this is working
# 0.99
# this is working
# 0
# this is working
# 1.45
# this is working
# 2.16
# this is working
# 1.99
# this is working
# 2.00
# this is working
# 0.99
# this is working
# 1.99
# this is working
# 1.99
# this is working
# 1.49
# this is working
# 1.45
# this is working
# 15.97
# this is working
# 29.83
# this is working
# 2.60
# this is working
# 6.09
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-7604ef0a2159> in <module>
#      14         # Parse HTML with Beautiful Soup
#      15         soup = BeautifulSoup(html, 'html.parser')
# ---> 16         time.sleep(3)
#      17     try:
#      18         # Retrieve all elements that contain book information
#
# KeyboardInterrupt:

# %%
alibris_pandas_df
# Out:
#                    ISBN Alibris Price
# 0     978-1-891830-75-4          3.40
# 1     978-1-60309-050-6          0.99
# 2     978-1-891830-71-6          1.45
# 3     978-1-60309-025-4          3.33
# 4     978-1-60309-047-6          6.74
# ..                  ...           ...
# 136   978-1-60309-049-0          1.45
# 137   978-1-60309-409-2         15.97
# 138   978-1-60309-381-1         29.83
# 139   978-1-60309-274-6          2.60
# 140  978-1-60309-355-2           6.09
#
# [141 rows x 2 columns]

# %%
final_df = pd.DataFrame.merge(book_pandas_df,alibris_pandas_df, on=["ISBN"])

# %%
final_df
# Out:
#                    ISBN                                    Title  Price  \
# 0     978-1-891830-75-4                                 110 Per¢  12.95
# 1     978-1-60309-050-6                    The 120 Days of Simon  14.95
# 2     978-1-891830-71-6               AEIOU or Any Easy Intimacy  12.00
# 3     978-1-60309-025-4               Alec: The Years Have Pants  35.00
# 4     978-1-60309-047-6  Alec: The Years Have Pants -- HARDCOVER  49.95
# ..                  ...                                      ...    ...
# 136   978-1-60309-049-0                          Moving Pictures  14.95
# 137   978-1-60309-409-2                    Nate Powell's OMNIBOX  59.99
# 138   978-1-60309-381-1          Nemo Trilogy (Slipcase Edition)  44.85
# 139   978-1-60309-274-6                       Nemo: Heart of Ice  14.95
# 140  978-1-60309-355-2                     Nemo: River of Ghosts  14.95
#
#     Alibris Price
# 0            3.40
# 1            0.99
# 2            1.45
# 3            3.33
# 4            6.74
# ..            ...
# 136          1.45
# 137         15.97
# 138         29.83
# 139          2.60
# 140          6.09
#
# [141 rows x 4 columns]

# %%
final_df.to_csv(r"book_prices.csv")
