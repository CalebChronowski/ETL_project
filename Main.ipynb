# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
link = 'http://www.topshelfcomix.com/catalog/isbn-list'

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
book_pandas_df = pd.DataFrame([])
browser.visit(link)
for y in range(1):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    air_comp = soup.find_all('div', class_='isbn-item')
    
    # Iterate through each book
    for air_comps in air_comp:
        part = air_comps.find('span',class_='isbn-number').text
        fact = air_comps.find('span', class_='isbn-info')
        price = air_comps.find('span', class_='isbn-info').text
        price = price.split("$")
        if len(price)<2:
            index=0
        else:
            index=1
        
        for facts in fact:
            desc = air_comps.find('a').text
        if len(price[index]) > 6:
            print("IT WORKED")
        else:
            book_pandas_df = book_pandas_df.append(pd.DataFrame({'Part Number': part, 'Description': desc,'Price':price[index]}, index=[0]), ignore_index=True)
    try:
        plwk = soup.find_all('a',rel='nofollow').text
        browser.click_link_by_text(plwk)
    except:
        print("Scraping Complete")
# Out:
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# Scraping Complete

# %%
book_pandas_df
# Out:
#            Part Number                                     Description  Price
# 0    978-1-891830-75-4                                        110 Per¢  12.95
# 1    978-1-60309-050-6                           The 120 Days of Simon  14.95
# 2    978-1-891830-71-6                      AEIOU or Any Easy Intimacy  12.00
# 3    978-1-60309-025-4                      Alec: The Years Have Pants  35.00
# 4    978-1-60309-047-6         Alec: The Years Have Pants -- HARDCOVER  49.95
# ..                 ...                                             ...    ...
# 252  978-1-60309-451-1    Nocturne: The Walled City Trilogy (Book Two)  39.99
# 253  978-1-60309-458-0                      A Radical Shift of Gravity  24.99
# 254  978-1-60309-463-4                                          Rascal  14.99
# 255  978-1-60309-466-5  The Grot: The Story of the Swamp City Grifters  24.99
# 256  978-1-60309-453-5                           Why Did We Trust Him?  14.99
#
# [257 rows x 3 columns]
