# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
link = 'http://www.topshelfcomix.com/catalog/isbn-list'

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
book_pandas_df = pd.DataFrame([])
browser.visit(link)
for y in range(1):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    air_comp = soup.find_all('div', class_='isbn-item')
    
    # Iterate through each book
    for air_comps in air_comp:
        part = air_comps.find('span',class_='isbn-number').text
        fact = air_comps.find('span', class_='isbn-info')
        price = air_comps.find('span', class_='isbn-info').text
        price = price.split("$")
        if len(price)<2:
            index=0
        else:
            index=1
        
        for facts in fact:
            desc = air_comps.find('a').text
        if len(price[index]) > 6:
            print("IT WORKED")
        else:
            book_pandas_df = book_pandas_df.append(pd.DataFrame({'ISBN': part, 'Title': desc,'Price':price[index]}, index=[0]), ignore_index=True)
    try:
        plwk = soup.find_all('a',rel='nofollow').text
        browser.click_link_by_text(plwk)
    except:
        print("Scraping Complete")
# Out:
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# IT WORKED
# Scraping Complete

# %%
links = book_pandas_df["ISBN"]

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

alibris_pandas_df = pd.DataFrame([])

#This doesn't work right now because there isn't a list of links
for x in links:

    url = (f'https://www.alibris.com/booksearch?keyword='+x)
    browser.visit(url)
    for y in range(1):
        # HTML object
        html = browser.html
        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')
    try:
        # Retrieve all elements that contain book information
        price = soup.find('meta',itemprop='price')['content']
        print("this is working")
        
        # Iterate through each book
        if price != 0:
            alibris_pandas_df = alibris_pandas_df.append(pd.DataFrame({'ISBN':x,'Alibris Price': price}, index=[0]), ignore_index=True)
            print(price)
    except TypeError:
        print("Oh Shit")
# Out:
# this is working
# 3.40
# this is working
# 0.99
# this is working
# 1.45
# this is working
# 3.33
# this is working
# 6.74
# this is working
# 1.45
# this is working
# 1.45
# this is working
# 1.45
# this is working
# 2.72
# this is working
# 2.77
# this is working
# 1.99
# this is working
# 1.48
# this is working
# 7.49
# this is working
# 25.56
# this is working
# 0
# this is working
# 17.81
# this is working
# 0
# this is working
# 1.49
# this is working
# 0.99
# this is working
# 1.46
# this is working
# 5.94
# this is working
# 1.80
# this is working
# 6.00
# this is working
# 12.51
# this is working
# 3.74
# this is working
# 1.99
# this is working
# 4.32
# this is working
# 2.77
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# Oh Shit
# this is working
# 1.79
# this is working
# 3.24
# this is working
# 1.21
# this is working
# 6.25
# this is working
# 8.64
# this is working
# 1.99
# this is working
# 5.15
# this is working
# 4.10
# this is working
# 12.92
# this is working
# 1.45
# ...

# %%
alibris_pandas_df
# Out:
#                  ISBN Alibris Price
# 0   978-1-891830-75-4          3.40
# 1   978-1-60309-050-6          0.99
# 2   978-1-891830-71-6          1.45
# 3   978-1-60309-025-4          3.33
# 4   978-1-60309-047-6          6.74
# 5   978-1-60309-322-4          1.45
# 6   978-1-891830-85-3          1.45
# 7   978-1-60309-016-2          1.45
# 8   978-1-60309-265-4          2.72
# 9   978-1-60309-077-3          2.77
# 10  978-1-60309-369-9          1.99
# 11  978-1-60309-069-8          1.48
# 12  978-1-60309-042-1          7.49
# 13  978-1-60309-026-1         25.56
# 14  978-1-60309-380-4             0
# 15  978-1-60309-027-8         17.81
# 16  978-1-60309-405-4             0
# 17  978-1-891830-37-2          1.49
# 18  978-1-60309-029-2          0.99
# 19  978-1-891830-40-2          1.46
# 20  978-1-60309-442-9          5.94
# 21  978-1-891830-56-3          1.80
# 22  978-1-60309-273-9          6.00
# 23  978-1-60309-432-0         12.51
# 24  978-1-60309-063-6          3.74
# ...
